# %% [markdown]
# # PPE Analysis using Ollama

# %% [markdown]
# ## Introduction
# Since we are exploring 2 models Llava:13B and Llamma3.2-Vision for PPE Analysis. We will follow steps mentioned bellow.
#
# _Note: If Ollama is not installed in your system, follow the steps given in given in [README.md](README.md) file._
#
# ### Step 1: Run the Ollama Model
# Open a new terminal/command prompt and run the following command based on the model to be used:<br>
#     ```
#     ollama run llava:13b
#     ```
#     <br>OR<br>
#     ```
#     ollama run llava:7b
#     ```
#     <br>OR<br>
#     ```
#     ollama run llamma3.2-vision
#     ```
#     <br>Once the model is running, keep the terminal/command prompt open for further steps.
#
# ### Step 2: Run this Notebook
# Start running this File. Make sure you replace the name of the model in the `model_name` variable.
# `model_name` can have two values - `llava:13b` or `llamma3.2-vision`.

# %% [markdown]
# ## The notebook is structured as follows:
#
# - **Data Preparation**: We start by loading our custom PPE dataset, which contains images from the medical, construction, and mining domains. The notebook demonstrates how to preprocess the images and prepare them for input into the VLM models.
# - **Model Loading and Initialization**: Next, we use OllaMa to load the LLaVa-13B and LLaMa3.2-Vision models. We'll explore the capabilities of these VLMs and discuss their suitability for the PPE analysis task.
# - **VLM-based PPE Detection**: The core of the notebook focuses on using the loaded VLM models to perform PPE detection on the input images. We'll showcase the code that leverages the models' computer vision and natural language processing abilities to identify the presence and types of PPE in the images.
# - **Results Evaluation and Analysis**: After the detection phase, we'll evaluate the performance of the VLM models on our PPE dataset. We'll analyze the accuracy, precision, recall, and other relevant metrics to understand the strengths and limitations of this approach.
# - **Visualizations and Insights**: To better interpret the model outputs, the notebook includes visualizations and techniques for highlighting the key PPE-related elements in the analyzed images. This helps provide deeper insights into the VLMs' decision-making process.
#
# By working through this notebook, you'll gain a solid understanding of how to use the OllaMa library and the LLaVa-13B and LLaMa3.2-Vision VLMs for PPE analysis. You'll also learn about the performance characteristics, advantages, and potential areas for improvement in this approach.

# %%
# Imports
import os
from pathlib import Path
import ollama
from PIL import Image
import base64
from io import BytesIO
import time
from IPython.display import HTML, display

# %%
def encode_image(image_path):
    """Convert image to base64"""
    with Image.open(image_path) as img:
        # Convert to RGB if needed
        if img.mode != 'RGB':
            img = img.convert('RGB')
        buffered = BytesIO()
        img.save(buffered, format="JPEG", quality=95)
        return base64.b64encode(buffered.getvalue()).decode()

def analyze_image(image_path, model_name):
    """Analyze single image with VLM"""
    try:
        # Encode image
        image_base64 = encode_image(image_path)
        
        # Create prompt following Ollama's format
        messages = [{
            "role": "user",
            "content": "Please describe in particular, the protective equipment being worn, if present.",
            "images": [image_base64]
        }]
        
        # Get VLM response
        response = ollama.chat(
            model=model_name,
            messages=messages
        )
        
        return response['message']['content']
        
    except Exception as e:
        print(f"Error analyzing {image_path}: {e}")
        return f"Error: {str(e)}"

def process_folder(folder_path, model_name, limit=None): 
    """Process all images in folder and return results or exit at the number specified"""
    results = []
    
    # Support multiple image extensions
    image_extensions = {'.jpg', '.jpeg', '.png', '.bmp'}

    # Get all image files
    image_files = [
        f for f in Path(folder_path).rglob('*')
        if f.suffix.lower() in image_extensions
    ]
    
    # Add this line to limit the number of images
    # if limit:
    #     image_files = image_files[:limit]
    
    print(f"Found {len(image_files)} images to process")
    
    # Process each image
    for i, image_path in enumerate(image_files, 1):
        print(f"Processing image {i}/{len(image_files)}: {image_path.name}")
        
        analysis = analyze_image(image_path, model_name)
        
        results.append({
            'image_path': str(image_path),
            'analysis': analysis
        })
        
        # Small delay to avoid overwhelming the API
        time.sleep(0.5)
    
    return results

# %%
# Visualizing and Saving the result as .html file.
def generate_html(results):
    """Generate HTML display of results"""
    html = """
    <style>
        .result-container {
            display: flex;
            margin-bottom: 20px;
            border: 1px solid #ddd;
            padding: 10px;
            border-radius: 5px;
        }
        .image-container {
            flex: 0 0 400px;
            margin-right: 20px;
        }
        .image-container img {
            max-width: 100%;
            height: auto;
        }
        .analysis-container {
            flex: 1;
            padding: 10px;
        }
        .analysis-text {
            white-space: pre-wrap;
            font-family: Arial, sans-serif;
        }
    </style>
    """
    
    for result in results:
        html += f"""
        <div class="result-container">
            <div class="image-container">
                <img src="file://{result['image_path']}" alt="Image">
                <p><small>{Path(result['image_path']).name}</small></p>
            </div>
            <div class="analysis-container">
                <div class="analysis-text">{result['analysis']}</div>
            </div>
        </div>
        """
    
    return html

def save_html(html_content, model_name, output_path):
    """Save HTML to file"""
    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(f"""
        <html>
        <head>
            <title>{model_name} Image Analysis Results</title>
        </head>
        <body>
            <h1>{model_name} Image Analysis Results</h1>
        """ + html_content + """
        </body>
        </html>
        """)

# %%
# Set the folder path containing images
image_folder = r'C:\Users\shrey\OneDrive - Process Point Technologies\vlm-ppe-analysis-toolkit\data\ppe-custom-data'

# Define Model to be used
model_name = "llava:7b"  # "llama3.2-vision"  # or 

# Process images
results = process_folder(image_folder, model_name) # Process all images
# results = process_folder(image_folder, limit=10) # Process only so many images

# Generate and display HTML in notebook
html_content = generate_html(results)
display(HTML(html_content))

# Save HTML file
save_html(html_content, model_name, r"C:\Users\shrey\OneDrive - Process Point Technologies\vlm-ppe-analysis-toolkit\results\llava7b_analysis_results.html")
# Out:
# Found 185 images to process
# Processing image 1/185: 0o18v965b30d1.jpeg
# Processing image 2/185: 13_CONSTRUCTION_SITE_WORKERS_FMT_09112021.jpg
# Processing image 3/185: 15454402121_60953d8737_b.jpg
# Processing image 4/185: 2+people+wearing+respirator+masks+-unsplashsml.jpg
# Processing image 5/185: 200519_qilei_song_ppe_covid_027-JPG--tojpeg_1589892792905_x2.jpg
# Processing image 6/185: 2021-01-06-PAPR-Kit-AMMACHI-Labs-Amrita-Hospital.jpg
# Processing image 7/185: 20210423_euromarc_NEW_WEB_CTA_S_TECMEN_11.jpg
# Processing image 8/185: 27015938380_f1cae4b9d4_b.jpg
# Processing image 9/185: 29984032326_0d8702fa5a_b.jpg
# Processing image 10/185: 3381804-man-wearing-respirator.jpg
# Processing image 11/185: 360_F_904532789_CO7JBxJNlkTk3LJULiNXrw7D36nB7EnM.jpg
# Processing image 12/185: 420631685.jpg
# Processing image 13/185: 47185000342_89b6e44653_b.jpg
# Processing image 14/185: 47185000382_bd00c6716c_b.jpg
# Processing image 15/185: 4957521446_a672f926a4_b.jpg
# Processing image 52/185: images (14).jpg
# Processing image 53/185: images (16).jpg
# Processing image 54/185: images (18).jpg
# Processing image 55/185: images (19).jpg
# Processing image 56/185: images (21).jpg
# Processing image 57/185: images (23).jpg
# Processing image 58/185: images (24).jpg
# Processing image 59/185: images (27).jpg
# Processing image 60/185: images (28).jpg
# Processing image 61/185: images (29).jpg
# Processing image 62/185: images (32).jpg
# Processing image 63/185: images (33).jpg
# Processing image 64/185: images (35).jpg
# Processing image 65/185: images (39).jpg
# Processing image 66/185: images (4).png
# Processing image 67/185: images (41).jpg
# Processing image 68/185: images (42).jpg
# Processing image 69/185: images (43).jpg
# Processing image 70/185: images (44).jpg
# Processing image 71/185: images (45).jpg
# Processing image 72/185: images (46).jpg
# Processing image 73/185: images (47).jpg
# Processing image 74/185: images (49).jpg
# Processing image 75/185: images (51).jpg
# Processing image 76/185: images (53).jpg
# Processing image 77/185: images (55).jpg
# Processing image 78/185: images (56).jpg
# Processing image 79/185: images (57).jpg
# Processing image 80/185: images (58).jpg
# Processing image 81/185: images (59).jpg
# Processing image 82/185: images (60).jpg
# Processing image 83/185: images (61).jpg
# Processing image 84/185: images (65).jpg
# Processing image 85/185: images (66).jpg
# Processing image 86/185: images (67).jpg
# Processing image 87/185: images (68).jpg
# Processing image 88/185: images (69).jpg
# Processing image 89/185: images (7).png
# Processing image 90/185: images (70).jpg
# Processing image 91/185: images (71).jpg
# Processing image 92/185: images (72).jpg
# Processing image 93/185: images (73).jpg
# Processing image 94/185: images (74).jpg
# Processing image 95/185: images (75).jpg
# Processing image 96/185: images (76).jpg
# Processing image 97/185: images (77).jpg
# Processing image 98/185: images (79).jpg
# Processing image 99/185: images (80).jpg
# Processing image 100/185: images (81).jpg
# Processing image 101/185: images (82).jpg
# Processing image 102/185: images (83).jpg
# Processing image 103/185: images (84).jpg
# Processing image 104/185: images (86).jpg
# Processing image 105/185: images (88).jpg
# Processing image 106/185: images (89).jpg
# Processing image 107/185: images (9).jpg
# Processing image 108/185: images (90).jpg
# Processing image 109/185: images (91).jpg
# Processing image 110/185: images (92).jpg
# Processing image 111/185: images (93).jpg
# Processing image 112/185: images (94).jpg
# Processing image 113/185: images (95).jpg
# Processing image 114/185: images (96).jpg
# Processing image 115/185: images (97).jpg
# Processing image 116/185: images (98).jpg
# Processing image 117/185: images (99).jpg
# Processing image 118/185: images - 2024-11-05T195225.066.jpg
# Processing image 119/185: images - 2024-11-05T195225.072.jpg
# Processing image 120/185: images - 2024-11-05T195225.080.jpg
# Processing image 121/185: images - 2024-11-05T195225.141.jpg
# Processing image 122/185: images - 2024-11-05T195225.147.jpg
# Processing image 123/185: images - 2024-11-05T195225.149.jpg
# Processing image 124/185: images - 2024-11-05T195225.152.jpg
# Processing image 125/185: images - 2024-11-05T195225.155.jpg
# Processing image 126/185: images - 2024-11-05T195225.158.jpg
# Processing image 127/185: images - 2024-11-05T195225.160.jpg
# Processing image 128/185: images - 2024-11-05T195225.162.jpg
# Processing image 129/185: images - 2024-11-05T195225.164.jpg
# Processing image 178/185: some_image2.jpg
# Processing image 179/185: some_image3.jpg
# Processing image 180/185: stock-photo-venice-beach-ca-usa-may-man-wearing-respirator-dust-mask-1874312635.jpg
# Processing image 181/185: thumbnail.jpg
# Processing image 182/185: woman-wearing-virus-protection-medical-face-mask-and-rubber-gloves.jpg
# Processing image 183/185: women-in-factory-wearing-protective-mask-goggles-and-respirator.jpg
# Processing image 184/185: young-man-wearing-n-respirator-dust-mask.jpg
# Processing image 185/185: Фильтрующий_СИЗОД_с_подачей_воздуха_для_ЧС.jpg
#     <style>
#         .result-container {
#             display: flex;
#             margin-bottom: 20px;
#             border: 1px solid #ddd;
#             padding: 10px;
#             border-radius: 5px;
#         }
#         .image-container {
#             flex: 0 0 400px;
#             margin-right: 20px;
#         }
#         .image-container img {
#             max-width: 100%;
#             height: auto;
#         }
#         .analysis-container {
#             flex: 1;
#             padding: 10px;
#         }
#         .analysis-text {
#             white-space: pre-wrap;
#             font-family: Arial, sans-serif;
#         }
#     </style>
#
#         <div class="result-container">
#             <div class="image-container">
#                 <img src="file://C:\Users\shrey\OneDrive - Process Point Technologies\vlm-ppe-analysis-toolkit\data\ppe-custom-data\0o18v965b30d1.jpeg" alt="Image">
#                 <p><small>0o18v965b30d1.jpeg</small></p>
#             </div>
#             <div class="analysis-container">
#                 <div class="analysis-text"> In the image, there is a person wearing protective equipment that includes a full-body suit with a white color, which appears to be a chemical or industrial type of outfit, often referred to as a "bunny suit" due to its large hood and full coverage. The suit may also include gloves and other protective gear, although the details are not clearly visible in this image.
#
# Additionally, there is a white respirator mask with filters on the front, which the person is wearing over their face. This type of mask is typically used to protect against chemicals, particles, or gases, such as those found in chemical spills, construction sites, or cleanroom environments. The overall look suggests that the person might be involved in an activity or profession that requires a high level of protection against various hazards. </div>
#             </div>
#         </div>
#
#         <div class="result-container">
#             <div class="image-container">
#                 <img src="file://C:\Users\shrey\OneDrive - Process Point Technologies\vlm-ppe-analysis-toolkit\data\ppe-custom-data\13_CONSTRUCTION_SITE_WORKERS_FMT_09112021.jpg" alt="Image">
#                 <p><small>13_CONSTRUCTION_SITE_WORKERS_FMT_09112021.jpg</small></p>
#             </div>
#             <div class="analysis-container">
#                 <div class="analysis-text"> In the image you've provided, it appears to show a construction site with several workers involved in various tasks. However, there is no clear indication of any protective equipment being worn by these individuals. The environment suggests that they are engaged in construction work, which typically requires safety gear such as hard hats, safety glasses or goggles, steel-toe boots, and high-visibility clothing. It's not possible to determine if this specific site follows all necessary safety protocols without a closer inspection of the workers and their activities. </div>
#             </div>
#         </div>
#
#         <div class="result-container">
#             <div class="image-container">
#                 <img src="file://C:\Users\shrey\OneDrive - Process Point Technologies\vlm-ppe-analysis-toolkit\data\ppe-custom-data\15454402121_60953d8737_b.jpg" alt="Image">
#                 <p><small>15454402121_60953d8737_b.jpg</small></p>
#             </div>
#             <div class="analysis-container">
#                 <div class="analysis-text"> In the image you've provided, there are two individuals wearing hard hats, which serve as head protection in construction settings to prevent injuries from falling objects or debris. They also appear to be wearing work gloves, which are commonly used for handling materials on a construction site. The environment suggests an active construction site with ongoing building activities, and the presence of protective equipment indicates that safety measures are being taken into consideration by those involved in the work. </div>
#             </div>
#         </div>
#
#         <div class="result-container">
#             <div class="image-container">
#                 <img src="file://C:\Users\shrey\OneDrive - Process Point Technologies\vlm-ppe-analysis-toolkit\data\ppe-custom-data\2+people+wearing+respirator+masks+-unsplashsml.jpg" alt="Image">
#                 <p><small>2+people+wearing+respirator+masks+-unsplashsml.jpg</small></p>
#             </div>
#             <div class="analysis-container">
#                 <div class="analysis-text"> In the image, there is a person on the right and another person on the left. Both individuals are wearing face masks with filters that cover their mouths and noses. The masks appear to be disposable surgical masks or respirators. There's also visible text on the filters, which is typically used to indicate the type of filter material within the mask. However, I am unable to provide specific details about the text on the filters due to the limitations of visual recognition. </div>
#             </div>
#         </div>
#
#         <div class="result-container">
#             <div class="image-container">
#                 <img src="file://C:\Users\shrey\OneDrive - Process Point Technologies\vlm-ppe-analysis-toolkit\data\ppe-custom-data\200519_qilei_song_ppe_covid_027-JPG--tojpeg_1589892792905_x2.jpg" alt="Image">
#                 <p><small>200519_qilei_song_ppe_covid_027-JPG--tojpeg_1589892792905_x2.jpg</small></p>
#             </div>
#             <div class="analysis-container">
#                 <div class="analysis-text"> In the image, we see a group of individuals in a healthcare setting that appears to be an operating room or similar clinical environment. The person on the left is wearing a surgical mask and cap, which are common types of personal protective equipment (PPE) used during medical procedures to prevent the spread of infectious particles from the surgical site. The person standing behind the stretcher is also wearing a surgical mask and cap.
#
# The remaining individuals in the image are wearing scrubs, which are typically worn by healthcare professionals such as nurses, surgeons, or other medical staff. Scrubs often include a head covering, sometimes referred to as a hairnet or bouffant, along with a pair of gloves. However, it is not clear from this angle and resolution whether these individuals are wearing masks or other PPE, as their faces are mostly obscured by the surgical cap and the surrounding environment.
#
# It's important to note that in healthcare settings, additional layers of PPE may be required depending on the type of procedure being performed and the level of risk associated with it. This image does not provide enough information to make any specific determinations about other potential PPE that might be used in this particular setting. </div>
#             </div>
#         </div>
#
#         <div class="result-container">
#             <div class="image-container">
#                 <img src="file://C:\Users\shrey\OneDrive - Process Point Technologies\vlm-ppe-analysis-toolkit\data\ppe-custom-data\2021-01-06-PAPR-Kit-AMMACHI-Labs-Amrita-Hospital.jpg" alt="Image">
#                 <p><small>2021-01-06-PAPR-Kit-AMMACHI-Labs-Amrita-Hospital.jpg</small></p>
#             </div>
#             <div class="analysis-container">
#                 <div class="analysis-text"> In the image you've provided, there appears to be a person wearing what looks like a full-body personal protective equipment (PPE) suit. The PPE suite is predominantly white and includes the following components:
#
# 1. A hooded coverall with a transparent visor on the front for visibility.
# 2. Gloves that are likely meant for handling contaminants, as they appear to be thick and designed for protection rather than dexterity.
# 3. A pair of safety boots, which are also white, matching the rest of the PPE suite.
# 4. Knee-high coverings that extend over the lower legs and feet.
# 5. An overall bodysuit that covers the torso and abdomen area with a zipper closure for ease of putting on or taking off.
# 6. A helmet

# %%
# import torch

# if torch.cuda.is_available():
#     print("GPU is active")
# else:
#     print("GPU is not active")
